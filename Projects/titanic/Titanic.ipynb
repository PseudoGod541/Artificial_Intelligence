# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# Loadind Data

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
passenger_id = test_data['PassengerId']

# %%
full_data = pd.concat([train_data.drop('Survived', axis=1), test_data], axis=0)

# %%
full_data
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1    female  38.0      1      0            PC 17599   71.2833   C85        C
# 2    female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3    female  35.0      1      0              113803   53.1000  C123        S
# 4      male  35.0      0      0              373450    8.0500   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %% [markdown]
# Feature Engineering

# %%
full_data['Title'] = full_data['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
full_data['Title'] = full_data['Title'].replace(['Lady', 'Countess','Capt','Col','Don','Dr','Major','Rev','Sir','Jonkheer','Dona'], 'Rare')
full_data['Title'] = full_data['Title'].replace('Mlle', 'Miss').replace('Ms', 'Miss').replace('Mme', 'Mrs')

# %%
full_data['FamilySize'] = full_data['SibSp'] + full_data['Parch'] + 1
full_data['IsAlone'] = (full_data['FamilySize'] == 1).astype(int)
full_data['CabinKnown'] = full_data['Cabin'].notnull().astype(int)

# %%
full_data
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1    female  38.0      1      0            PC 17599   71.2833   C85        C
# 2    female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3    female  35.0      1      0              113803   53.1000  C123        S
# 4      male  35.0      0      0              373450    8.0500   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
#       Title  FamilySize  IsAlone  CabinKnown
# 0        Mr           2        0           0
# 1       Mrs           2        0           1
# 2      Miss           1        1           0
# 3       Mrs           2        0           1
# 4        Mr           1        1           0
# ..      ...         ...      ...         ...
# 413      Mr           1        1           0
# 414    Rare           1        1           1
# 415      Mr           1        1           0
# 416      Mr           1        1           0
# 417  Master           3        0           0
#
# [1309 rows x 15 columns]

# %% [markdown]
# Dropping Unneeded feature

# %%
full_data = full_data.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)

# %% [markdown]
# Separate back into train/test

# %%
X = full_data.iloc[:len(train_data), :]
X_test_final = full_data.iloc[len(train_data):, :]
y = train_data['Survived']

# %% [markdown]
# Define preprocessing

# %%
num_features = ['Age', 'Fare', 'FamilySize']
cat_features = ['Sex', 'Embarked', 'Pclass', 'Title', 'IsAlone', 'CabinKnown']

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(transformers=[
    ('num', numeric_transformer, num_features),
    ('cat', categorical_transformer, cat_features)
])

# %% [markdown]
# Applying Preprocessing

# %%
X_processed = preprocessor.fit_transform(X)
X_test_processed = preprocessor.transform(X_test_final)

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)

# %% [markdown]
# Deep Learning Model

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Early stopping

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %% [markdown]
# Train

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, callbacks=[early_stop], verbose=1)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.5516 - loss: 0.6902 - val_accuracy: 0.6592 - val_loss: 0.6105
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7054 - loss: 0.5824 - val_accuracy: 0.7654 - val_loss: 0.5305
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7554 - loss: 0.5228 - val_accuracy: 0.7933 - val_loss: 0.4846
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7931 - loss: 0.5021 - val_accuracy: 0.8045 - val_loss: 0.4616
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8195 - loss: 0.4425 - val_accuracy: 0.8045 - val_loss: 0.4484
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8029 - loss: 0.4687 - val_accuracy: 0.8101 - val_loss: 0.4442
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8142 - loss: 0.4305 - val_accuracy: 0.8101 - val_loss: 0.4414
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8107 - loss: 0.4415 - val_accuracy: 0.8101 - val_loss: 0.4395
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8466 - loss: 0.4214 - val_accuracy: 0.8101 - val_loss: 0.4391
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8358 - loss: 0.3953 - val_accuracy: 0.8045 - val_loss: 0.4347
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8050 - loss: 0.4579 - val_accuracy: 0.8045 - val_loss: 0.4405
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8265 - loss: 0.4399 - val_accuracy: 0.8045 - val_loss: 0.4384
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8318 - loss: 0.4367 - val_accuracy: 0.8045 - val_loss: 0.4340
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8478 - loss: 0.3807 - val_accuracy: 0.8045 - val_loss: 0.4389
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8494 - loss: 0.3935 - val_accuracy: 0.8101 - val_loss: 0.4377
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8497 - loss: 0.4004 - val_accuracy: 0.8101 - val_loss: 0.4404
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8378 - loss: 0.4260 - val_accuracy: 0.8101 - val_loss: 0.4374
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8409 - loss: 0.3911 - val_accuracy: 0.8101 - val_loss: 0.4349
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8337 - loss: 0.4014 - val_accuracy: 0.8156 - val_loss: 0.4405
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8574 - loss: 0.3854 - val_accuracy: 0.8156 - val_loss: 0.4384
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8628 - loss: 0.3540 - val_accuracy: 0.8101 - val_loss: 0.4413
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8254 - loss: 0.4405 - val_accuracy: 0.8156 - val_loss: 0.4352
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8277 - loss: 0.4150 - val_accuracy: 0.8101 - val_loss: 0.4318
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8348 - loss: 0.4145 - val_accuracy: 0.8045 - val_loss: 0.4324
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8464 - loss: 0.3871 - val_accuracy: 0.8156 - val_loss: 0.4367
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8249 - loss: 0.4182 - val_accuracy: 0.8101 - val_loss: 0.4372
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8557 - loss: 0.3674 - val_accuracy: 0.8101 - val_loss: 0.4448
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8454 - loss: 0.3746 - val_accuracy: 0.8156 - val_loss: 0.4476
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8531 - loss: 0.3750 - val_accuracy: 0.8101 - val_loss: 0.4389
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8552 - loss: 0.3774 - val_accuracy: 0.8156 - val_loss: 0.4450
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8342 - loss: 0.4063 - val_accuracy: 0.8101 - val_loss: 0.4363
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8249 - loss: 0.4214 - val_accuracy: 0.8156 - val_loss: 0.4383
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8434 - loss: 0.3788 - val_accuracy: 0.8212 - val_loss: 0.4427

# %% [markdown]
# Evaluation

# %%
val_preds = (model.predict(X_test) > 0.5).astype(int)
print("Validation Accuracy:", accuracy_score(y_test, val_preds))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Validation Accuracy: 0.8100558659217877

# %% [markdown]
# Predict for Submission

# %%
final_preds = (model.predict(X_test_processed) > 0.5).astype(int)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# Create submission

# %%
submission = pd.DataFrame({'PassengerId': passenger_id, 'Survived': final_preds.ravel().astype(int)})
submission.to_csv('titanic_dl_submission.csv', index=False)
